# %% [markdown]
# ### Objective
# To learn and implement basic PySpark operations like:
# - Fetching data from local system
# - DataFrame creation
# - Filtering
# - Feature engineering
# ### Tools Used
# - PySpark
# - Google Colab

# %%
# !pip install pyspark
# ! is used to tell collab run this commmand as shell code not as python code

# %% [markdown]
# # Step 1: Importing Libraries

# %%
# from pyspark.sql import SparkSession
# #like ye hum sessin create krne ke liye use krte h means hum ek enginee bna rhe h phle phir start krte h baad m
# spark= SparkSession.builder.getOrCreate()# yaha humne settings set ki using builder use get if any spark already runing
# #then use the same spark or create a new one
# print("Spark is running")

# %%
# data=[("Birender",20,"gurugram"),("vivek",20,"haryana"),("Sona",15,"mumbai")]
# column=["Name","Age","state"]
# df=spark.createDataFrame(data,column)
# df.show()
# df.printSchema()

# %%
#df.groupby("Age").count().show()

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.getOrCreate()

# %% [markdown]
# # Step 2: Creating Hardcoded Data (Temporary Solution)
#
# Since using a CSV file from my local system can cause accessibility issues
# (for example, others won’t have access to the same file path), I am using
# hardcoded data in this step to ensure the notebook runs successfully for everyone.
#
# In the upcoming steps, I will switch to loading the dataset from a GitHub link
# so that the notebook becomes fully reproducible and easy for others (like my mentor) to review.

# %%
data = [
    ("Krish","Data Science",10000),
    ("Krish","IOT",5000),
    ("Mahesh","Big Data",4000),
    ("Krish","Big Data",4000),
    ("Mahesh","Data Science",3000),
    ("Sudhanshu","Data Science",20000),
    ("Sudhanshu","IOT",10000),
    ("Sudhanshu","Big Data",5000),
    ("Sunny","Data Science",10000),
    ("Sunny","Big Data",2000)
]

columns = ["Name","Department","Salary"]

df = spark.createDataFrame(data, columns)

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://0b9bcb2b0cf5:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# #Just showing the dataset

# %%
df.show()
# Out:
# +---------+------------+------+
# |     Name|  Department|Salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |    Krish|    Big Data|  4000|
# |   Mahesh|Data Science|  3000|
# |Sudhanshu|Data Science| 20000|
# |Sudhanshu|         IOT| 10000|
# |Sudhanshu|    Big Data|  5000|
# |    Sunny|Data Science| 10000|
# |    Sunny|    Big Data|  2000|
# +---------+------------+------+

# %%
type(df)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df.head(2)
# Out:
# [Row(Name='Krish', Department='Data Science', Salary=10000),
#  Row(Name='Krish', Department='IOT', Salary=5000)]

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- Salary: long (nullable = true)

# %%
df.columns
# Out:
# ['Name', 'Department', 'Salary']

# %% [markdown]
# #Showing first 2 element of dataset

# %%
df.head(2)# so pandas m data frame m show hota h
#but pyspark m ese raw list of tuple m show hota h
# Out:
# [Row(Name='Krish', Department='Data Science', Salary=10000),
#  Row(Name='Krish', Department='IOT', Salary=5000)]

# %%
df.show()
# Out:
# +---------+------------+------+
# |     Name|  Department|Salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |    Krish|    Big Data|  4000|
# |   Mahesh|Data Science|  3000|
# |Sudhanshu|Data Science| 20000|
# |Sudhanshu|         IOT| 10000|
# |Sudhanshu|    Big Data|  5000|
# |    Sunny|Data Science| 10000|
# |    Sunny|    Big Data|  2000|
# +---------+------------+------+

# %% [markdown]
# #using select to see a specific field or element

# %%
df.select('Name')
# Out:
# DataFrame[Name: string]

# %%
df.select('Name','Department').show()
# Out:
# +---------+------------+
# |     Name|  Department|
# +---------+------------+
# |    Krish|Data Science|
# |    Krish|         IOT|
# |   Mahesh|    Big Data|
# |    Krish|    Big Data|
# |   Mahesh|Data Science|
# |Sudhanshu|Data Science|
# |Sudhanshu|         IOT|
# |Sudhanshu|    Big Data|
# |    Sunny|Data Science|
# |    Sunny|    Big Data|
# +---------+------------+

# %%
df['name']
# Out:
# Column<'name'>

# %%
df.dtypes
#to see data types
# Out:
# [('Name', 'string'), ('Department', 'string'), ('Salary', 'bigint')]

# %% [markdown]
# #using describe funcation to see overall mean,median,mode and standard deviation

# %%
df.describe().show()
# Out:
# +-------+-----+----------+-----------------+
# |summary| Name|Department|           Salary|
# +-------+-----+----------+-----------------+
# |  count|   10|        10|               10|
# |   mean| NULL|      NULL|           7300.0|
# | stddev| NULL|      NULL|5396.500923952689|
# |    min|Krish|  Big Data|             2000|
# |    max|Sunny|       IOT|            20000|
# +-------+-----+----------+-----------------+

# %% [markdown]
# #Making a new column using experience column

# %%
df=df.withColumn('Salary after 2 year',df['Salary']+2000)

# %%
df.show()
# Out:
# +---------+------------+------+-------------------+
# |     Name|  Department|Salary|Salary after 2 year|
# +---------+------------+------+-------------------+
# |    Krish|Data Science| 10000|              12000|
# |    Krish|         IOT|  5000|               7000|
# |   Mahesh|    Big Data|  4000|               6000|
# |    Krish|    Big Data|  4000|               6000|
# |   Mahesh|Data Science|  3000|               5000|
# |Sudhanshu|Data Science| 20000|              22000|
# |Sudhanshu|         IOT| 10000|              12000|
# |Sudhanshu|    Big Data|  5000|               7000|
# |    Sunny|Data Science| 10000|              12000|
# |    Sunny|    Big Data|  2000|               4000|
# +---------+------------+------+-------------------+

# %%
df=df.drop('Salary after 2 year')
df.show()
# Out:
# +---------+------------+------+
# |     Name|  Department|Salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |    Krish|    Big Data|  4000|
# |   Mahesh|Data Science|  3000|
# |Sudhanshu|Data Science| 20000|
# |Sudhanshu|         IOT| 10000|
# |Sudhanshu|    Big Data|  5000|
# |    Sunny|Data Science| 10000|
# |    Sunny|    Big Data|  2000|
# +---------+------------+------+

# %% [markdown]
# #just renaming column

# %%
df=df.withColumnRenamed('name','new_name')
df.show()
# Out:
# +---------+------------+------+
# | new_name|  Department|Salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |    Krish|    Big Data|  4000|
# |   Mahesh|Data Science|  3000|
# |Sudhanshu|Data Science| 20000|
# |Sudhanshu|         IOT| 10000|
# |Sudhanshu|    Big Data|  5000|
# |    Sunny|Data Science| 10000|
# |    Sunny|    Big Data|  2000|
# +---------+------------+------+

# %% [markdown]
# ### Conclusion
# This notebook demonstrates fundamental PySpark operations including DataFrame creation, filtering, and basic feature engineering.
#
# To ensure ease of access and reproducibility, I replaced the original CSV-based dataset with a hardcoded dataset, while maintaining the same transformation logic.
#
# This helped me understand how to work with both external data sources and in-memory data structures in PySpark.
#
# I will be covering more advanced topics in upcoming notebooks.
#
# Grateful to Hardik Sir for continuous guidance.
